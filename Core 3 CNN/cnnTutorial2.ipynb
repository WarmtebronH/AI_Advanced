# %% [markdown]
# # How to Develop a CNN From Scratch for CIFAR-10 Photo Classification

# %% [markdown]
# The dataset is comprised of 60,000 32×32 pixel color photographs of objects from 10 classes, such as frogs, birds, cats, ships, etc. The class labels and their standard associated integer values are listed below.
#
# 0: airplane<br>
# 1: automobile<br>
# 2: bird<br>
# 3: cat<br>
# 4: deer<br>
# 5: dog<br>
# 6: frog<br>
# 7: horse<br>
# 8: ship<br>
# 9: truck<br>

# %% [markdown]
# ## Step 1: Import the necessary libraries
#
# We will use Keras, a high-level deep learning library, to implement our CNN. We'll also use some other Python libraries to help us with data preprocessing and visualization.

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Step 2: Load the CIFAR-10 dataset
#
# We will be using the CIFAR-10 dataset, which consists of 60,000 32x32 color images in 10 classes, with 6,000 images per class. There are 50,000 training images and 10,000 test images.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Step 3: Preprocess the data
#
# We need to preprocess the data before we can use it to train our CNN. First, we'll normalize the pixel values to be between 0 and 1. Then, we'll one-hot encode the class labels.

# %%
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ## Step 4: Define the CNN architecture
#
# We'll define our CNN architecture using the Sequential model in Keras. Our CNN will have the following layers:
#
# - Convolutional layer with 32 filters, 3x3 kernel size, and ReLU activation function
# - Max pooling layer with 2x2 pool size
# - Convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation function
# - Max pooling layer with 2x2 pool size
# - Flatten layer to convert the output of the convolutional layers into a 1D feature vector
# - Fully connected layer with 512 units and ReLU activation function
# - Output layer with 10 units and softmax activation function

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# ## Step 5: Compile the model
#
# Before we can train the model, we need to compile it. We'll use categorical cross-entropy as our loss function, Adam as our optimizer, and accuracy as our evaluation metric.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Step 6: Train the model
#
# We'll train the model using the fit() method in Keras. We'll pass in our preprocessed training data X_train and y_train, specify a batch size of 32, train for 50 epochs, and use our preprocessed test data X_test and y_test as validation data.
#
# The fit() method returns a History object which we'll store in the history variable. This object contains information about the training and validation accuracy and loss for each epoch.

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 1.3469 - accuracy: 0.5200 - val_loss: 1.0881 - val_accuracy: 0.6243
# Epoch 2/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.9690 - accuracy: 0.6613 - val_loss: 0.9905 - val_accuracy: 0.6564
# Epoch 3/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.7890 - accuracy: 0.7257 - val_loss: 0.9250 - val_accuracy: 0.6829
# Epoch 4/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.6418 - accuracy: 0.7768 - val_loss: 0.8731 - val_accuracy: 0.7043
# Epoch 5/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.5037 - accuracy: 0.8246 - val_loss: 0.8866 - val_accuracy: 0.7185
# Epoch 6/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.3746 - accuracy: 0.8711 - val_loss: 0.9713 - val_accuracy: 0.7067
# Epoch 7/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.2718 - accuracy: 0.9071 - val_loss: 1.1253 - val_accuracy: 0.6972
# Epoch 8/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.1873 - accuracy: 0.9350 - val_loss: 1.2400 - val_accuracy: 0.7129
# Epoch 9/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1403 - accuracy: 0.9524 - val_loss: 1.3262 - val_accuracy: 0.7095
# Epoch 10/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.1149 - accuracy: 0.9601 - val_loss: 1.5505 - val_accuracy: 0.7024
# Epoch 11/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0941 - accuracy: 0.9668 - val_loss: 1.7260 - val_accuracy: 0.6897
# Epoch 12/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0902 - accuracy: 0.9690 - val_loss: 1.7770 - val_accuracy: 0.7029
# Epoch 13/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0765 - accuracy: 0.9741 - val_loss: 1.8596 - val_accuracy: 0.6955
# Epoch 14/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0828 - accuracy: 0.9723 - val_loss: 1.9171 - val_accuracy: 0.6982
# Epoch 15/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0692 - accuracy: 0.9767 - val_loss: 1.9441 - val_accuracy: 0.7055
# Epoch 16/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0664 - accuracy: 0.9783 - val_loss: 2.1425 - val_accuracy: 0.7013
# Epoch 17/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0651 - accuracy: 0.9782 - val_loss: 2.1875 - val_accuracy: 0.6963
# Epoch 18/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0557 - accuracy: 0.9813 - val_loss: 2.1696 - val_accuracy: 0.6979
# Epoch 19/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0649 - accuracy: 0.9788 - val_loss: 2.3058 - val_accuracy: 0.7037
# Epoch 20/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0536 - accuracy: 0.9829 - val_loss: 2.4510 - val_accuracy: 0.7016
# Epoch 21/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0559 - accuracy: 0.9811 - val_loss: 2.5700 - val_accuracy: 0.6993
# Epoch 22/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0580 - accuracy: 0.9819 - val_loss: 2.4426 - val_accuracy: 0.6997
# Epoch 23/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0530 - accuracy: 0.9833 - val_loss: 2.6057 - val_accuracy: 0.7006
# Epoch 24/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0521 - accuracy: 0.9839 - val_loss: 2.5881 - val_accuracy: 0.7033
# Epoch 25/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0540 - accuracy: 0.9831 - val_loss: 2.7933 - val_accuracy: 0.6948
# Epoch 26/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0471 - accuracy: 0.9848 - val_loss: 2.7458 - val_accuracy: 0.6891
# Epoch 27/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0541 - accuracy: 0.9834 - val_loss: 2.7076 - val_accuracy: 0.7002
# Epoch 28/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0459 - accuracy: 0.9860 - val_loss: 2.8957 - val_accuracy: 0.6945
# Epoch 29/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0507 - accuracy: 0.9847 - val_loss: 2.8626 - val_accuracy: 0.6964
# Epoch 30/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0423 - accuracy: 0.9869 - val_loss: 2.8938 - val_accuracy: 0.6971
# Epoch 31/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0431 - accuracy: 0.9869 - val_loss: 2.9663 - val_accuracy: 0.6942
# Epoch 32/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0542 - accuracy: 0.9835 - val_loss: 3.0546 - val_accuracy: 0.6956
# Epoch 33/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0422 - accuracy: 0.9877 - val_loss: 3.0414 - val_accuracy: 0.7003
# Epoch 34/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0413 - accuracy: 0.9878 - val_loss: 3.1985 - val_accuracy: 0.7069
# Epoch 35/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0481 - accuracy: 0.9860 - val_loss: 3.2553 - val_accuracy: 0.6895
# Epoch 36/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0415 - accuracy: 0.9882 - val_loss: 3.2658 - val_accuracy: 0.6950
# Epoch 37/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0445 - accuracy: 0.9870 - val_loss: 3.3326 - val_accuracy: 0.7005
# Epoch 38/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0397 - accuracy: 0.9886 - val_loss: 3.1696 - val_accuracy: 0.6987
# Epoch 39/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0372 - accuracy: 0.9884 - val_loss: 3.4634 - val_accuracy: 0.6848
# Epoch 40/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0367 - accuracy: 0.9889 - val_loss: 3.3504 - val_accuracy: 0.6923
# Epoch 41/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0408 - accuracy: 0.9879 - val_loss: 3.4091 - val_accuracy: 0.6973
# Epoch 42/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0412 - accuracy: 0.9884 - val_loss: 3.6214 - val_accuracy: 0.6953
# Epoch 43/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0411 - accuracy: 0.9884 - val_loss: 3.4790 - val_accuracy: 0.6983
# Epoch 44/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0362 - accuracy: 0.9893 - val_loss: 3.8888 - val_accuracy: 0.6916
# Epoch 45/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0409 - accuracy: 0.9887 - val_loss: 3.7373 - val_accuracy: 0.6841
# Epoch 46/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0395 - accuracy: 0.9883 - val_loss: 3.7588 - val_accuracy: 0.6889
# Epoch 47/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0377 - accuracy: 0.9896 - val_loss: 3.8179 - val_accuracy: 0.6929
# Epoch 48/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0436 - accuracy: 0.9883 - val_loss: 3.7403 - val_accuracy: 0.6944
# Epoch 49/50
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.0369 - accuracy: 0.9897 - val_loss: 3.9516 - val_accuracy: 0.6890
# Epoch 50/50
# 1563/1563 [==============================] - 23s 14ms/step - loss: 0.0319 - accuracy: 0.9910 - val_loss: 3.7683 - val_accuracy: 0.7034

# %% [markdown]
# ## Step 7: Evaluate the model
#
# After training our CNN, we'll evaluate its performance on the test set using the evaluate() method in Keras. We'll print out the test loss and accuracy.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 3.7683 - accuracy: 0.7034
# Test loss: 3.7682883739471436
# Test accuracy: 0.7034000158309937

# %% [markdown]
# ## Step 8: Visualize the training history
#
# We can visualize the training and validation accuracy and loss over the epochs using the history object.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# These plots show us how the accuracy and loss change over the epochs for the training and validation sets. If the training accuracy is much higher than the validation accuracy, it could be a sign of overfitting.
#
# And that's it! You've successfully built and trained a CNN from scratch for CIFAR-10 photo classification.
