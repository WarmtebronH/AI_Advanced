# %%
import pandas as pd

data = pd.read_csv('rawData.csv', delimiter=";")

# %%
data
# Out:
#        id                                               name  start_date  \
# 0      10                                 NSA vs. US muslims  2002-01-01
# 1      16                                      Athens Affair  2004-07-01
# 2      21                                 NSA vs. Al Jazeera  2006-01-01
# 3      22                                   NSA vs. Aeroflot  2006-01-01
# 4      23           PLA vs. Westinghouse Electric & US Steel  2006-01-01
# ..    ...                                                ...         ...
# 193  1400                                         SockDetour  2021-07-27
# 194  1401  U.S. State Governments Targeted by Chinese Hac...  2021-05-01
# 195  1414                            ColunmTK (Supply Chain)  2021-02-01
# 196  1448                 Ukraine government site defacement  2022-01-13
# 197  1607  Chinese state-sponsored Winnti Group targets H...  2021-01-01
#
#        end_date                                     initiator_name  \
# ...
