# %% [markdown]
# # Data Preperation

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd

# %%
data = pd.read_csv('observation.csv')
data
# Out:
#                id                                          image_url  \
# 0              39  https://inaturalist-open-data.s3.amazonaws.com...
# 1              40  https://inaturalist-open-data.s3.amazonaws.com...
# 2              80  https://inaturalist-open-data.s3.amazonaws.com...
# 3             203  http://static.inaturalist.org/photos/132/mediu...
# 4             523  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 303675  156384671  https://static.inaturalist.org/photos/27041880...
# 303676  156387550  https://inaturalist-open-data.s3.amazonaws.com...
# 303677  156391245  https://static.inaturalist.org/photos/27043003...
# 303678  156392005  https://inaturalist-open-data.s3.amazonaws.com...
# 303679  156400272  https://inaturalist-open-data.s3.amazonaws.com...
#
#                    scientific_name                      common_name  \
# 0                   Taricha torosa                  California Newt
# 1                   Taricha torosa                  California Newt
# 2          Callisaurus draconoides              Zebra-tailed Lizard
# 3                Arctia virginalis            Ranchman's Tiger Moth
# 4              Malacosoma disstria     Forest Tent Caterpillar Moth
# ...                            ...                              ...
# 303675  Duttaphrynus melanostictus                Asian Common Toad
# 303676                   Bufo bufo                       Gewone Pad
# 303677         Crotalus adamanteus  Eastern Diamondback Rattlesnake
# 303678                Hyla arborea                       Boomkikker
# 303679            Zamenis scalaris                        Trapslang
#
#        iconic_taxon_name
# 0               Amphibia
# 1               Amphibia
# 2               Reptilia
# 3                Insecta
# 4                Insecta
# ...                  ...
# 303675          Amphibia
# 303676          Amphibia
# 303677          Reptilia
# 303678          Amphibia
# 303679          Reptilia
#
# [303680 rows x 5 columns]

# %% [markdown]
# ## 2. Check empty values.
#
# ###  Check empty values in image_url
# I am going to check whether there are any rows with the same scientific_name, where one of the rows has an image URL and the other does not. This will allow me to transfer the URL from the row containing the URL to the row with the empty URL.

# %%
# Count the number of empty 'image_url' values
num_empty_image_urls = data['image_url'].isna().sum()

# Print the number of empty 'image_url' values
print(f"Number of empty 'image_url' values: {num_empty_image_urls}")
# Out:
# Number of empty 'image_url' values: 1032

# %%
# Find the rows with empty 'image_url' values
empty_image_url_rows = data.loc[data['image_url'].isna()]

# Iterate through the empty 'image_url' rows
for index, row in empty_image_url_rows.iterrows():
    # Find a row with the same 'scientific_name' and non-empty 'image_url'
    matching_row = data.loc[
        (data['scientific_name'] == row['scientific_name']) &
        (~data['image_url'].isna())
    ].head(1)

    # If a matching row is found
    if not matching_row.empty:
        # Copy the 'image_url' value from the matching row to the current row
        data.loc[index, 'image_url'] = matching_row['image_url'].values[0]

# Print the updated dataset
data
# Out:
#                id                                          image_url  \
# 0              39  https://inaturalist-open-data.s3.amazonaws.com...
# 1              40  https://inaturalist-open-data.s3.amazonaws.com...
# 2              80  https://inaturalist-open-data.s3.amazonaws.com...
# 3             203  http://static.inaturalist.org/photos/132/mediu...
# 4             523  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 303675  156384671  https://static.inaturalist.org/photos/27041880...
# 303676  156387550  https://inaturalist-open-data.s3.amazonaws.com...
# 303677  156391245  https://static.inaturalist.org/photos/27043003...
# 303678  156392005  https://inaturalist-open-data.s3.amazonaws.com...
# 303679  156400272  https://inaturalist-open-data.s3.amazonaws.com...
#
#                    scientific_name                      common_name  \
# 0                   Taricha torosa                  California Newt
# 1                   Taricha torosa                  California Newt
# 2          Callisaurus draconoides              Zebra-tailed Lizard
# 3                Arctia virginalis            Ranchman's Tiger Moth
# 4              Malacosoma disstria     Forest Tent Caterpillar Moth
# ...                            ...                              ...
# 303675  Duttaphrynus melanostictus                Asian Common Toad
# 303676                   Bufo bufo                       Gewone Pad
# 303677         Crotalus adamanteus  Eastern Diamondback Rattlesnake
# 303678                Hyla arborea                       Boomkikker
# 303679            Zamenis scalaris                        Trapslang
#
#        iconic_taxon_name
# 0               Amphibia
# 1               Amphibia
# 2               Reptilia
# 3                Insecta
# 4                Insecta
# ...                  ...
# 303675          Amphibia
# 303676          Amphibia
# 303677          Reptilia
# 303678          Amphibia
# 303679          Reptilia
#
# [303680 rows x 5 columns]

# %% [markdown]
# #### Check if there are still empty values in the Image_url.
#
# I will verify whether there are any remaining empty values in the Image_url column. If there are, I will exclude those rows as they will not be useful for image classification.

# %%
# Count the number of empty 'image_url' values
num_empty_image_urls = data['image_url'].isna().sum()

# Print the number of empty 'image_url' values
print(f"Number of empty 'image_url' values: {num_empty_image_urls}")
# Out:
# Number of empty 'image_url' values: 14

# %% [markdown]
# As there are still 14 rows that lack an image URL, my next step is to remove those rows

# %%
# Remove rows with empty 'image_url' values
data = data.dropna(subset=['image_url'])

# Count the number of empty 'image_url' values
num_empty_image_urls = data['image_url'].isna().sum()

# Print the number of empty 'image_url' values
print(f"Number of empty 'image_url' values: {num_empty_image_urls}")
# Out:
# Number of empty 'image_url' values: 0

# %% [markdown]
# ### Check empty values in common name.

# %%
# Check for missing values in the common_name column
missing_common_names = data['common_name'].isnull()

# Count the number of missing common names
num_missing_common_names = missing_common_names.sum()

# Print the number of missing common names
print(f"There are {num_missing_common_names} missing common names in the data.")
# Out:
# There are 27766 missing common names in the data.

# %% [markdown]
# I want to verify if it is possible to copy the missing `common_name` values when the `common_name` column is empty (NaN) and the `scientific_name` column matches a row where the `common_name` is not empty.

# %%
def check_common_name_variations(group):
    has_nan = group['common_name'].isna().any()
    has_value = group['common_name'].notna().any()
    return has_nan and has_value

groups = data.groupby('scientific_name')
duplicates_with_varied_common_names = groups.apply(check_common_name_variations)
duplicates_with_varied_common_names = duplicates_with_varied_common_names[duplicates_with_varied_common_names]

print(f"There is {len(duplicates_with_varied_common_names)} scientific name where some common name values are missing.")
print(duplicates_with_varied_common_names)
# Out:
# There is 1 scientific name where some common name values are missing.
# scientific_name
# Leptidea sinapis    True
# dtype: bool

# %%
# Select the rows with the matching scientific name
matching_rows = data.loc[data['scientific_name'] == 'Leptidea sinapis']

# Output the matching rows
matching_rows
# Out:
#                id                                          image_url  \
# 40298    15382084  https://inaturalist-open-data.s3.amazonaws.com...
# 44516    16896561  https://inaturalist-open-data.s3.amazonaws.com...
# 50741    19247806  https://inaturalist-open-data.s3.amazonaws.com...
# 58898    22762965  https://static.inaturalist.org/photos/35275688...
# 59027    22831485  https://inaturalist-open-data.s3.amazonaws.com...
# 64060    25905213  https://static.inaturalist.org/photos/40140062...
# 79322    31351142  https://inaturalist-open-data.s3.amazonaws.com...
# 101936   41908484  https://inaturalist-open-data.s3.amazonaws.com...
# 103205   42480138  https://inaturalist-open-data.s3.amazonaws.com...
# 107365   45149613  https://static.inaturalist.org/photos/71584977...
# 108329   45657377  https://inaturalist-open-data.s3.amazonaws.com...
# 115152   49051665  https://inaturalist-open-data.s3.amazonaws.com...
# 134990   57330320  https://inaturalist-open-data.s3.amazonaws.com...
# 140985   59880178  https://inaturalist-open-data.s3.amazonaws.com...
# 140986   59880498  https://inaturalist-open-data.s3.amazonaws.com...
# 174040   78499732  https://inaturalist-open-data.s3.amazonaws.com...
# 193162   88578969  https://inaturalist-open-data.s3.amazonaws.com...
# 234974  111026645  https://inaturalist-open-data.s3.amazonaws.com...
# 237760  112822538  https://inaturalist-open-data.s3.amazonaws.com...
# 247598  120067723  https://inaturalist-open-data.s3.amazonaws.com...
# 247853  120198072  https://inaturalist-open-data.s3.amazonaws.com...
# 252716  123045521  https://static.inaturalist.org/photos/20840729...
# 263188  128794872  https://inaturalist-open-data.s3.amazonaws.com...
# 272342  133913132  https://static.inaturalist.org/photos/22817324...
# 286903  143708570  https://inaturalist-open-data.s3.amazonaws.com...
# 297049  150355290  https://inaturalist-open-data.s3.amazonaws.com...
# 299161  151866366  https://inaturalist-open-data.s3.amazonaws.com...
# 300645  152977712  https://inaturalist-open-data.s3.amazonaws.com...
#
#          scientific_name common_name iconic_taxon_name
# 40298   Leptidea sinapis  Wood White           Insecta
# 44516   Leptidea sinapis  Wood White           Insecta
# 50741   Leptidea sinapis  Wood White           Insecta
# 58898   Leptidea sinapis  Wood White           Insecta
# 59027   Leptidea sinapis  Wood White           Insecta
# 64060   Leptidea sinapis  Wood White           Insecta
# 79322   Leptidea sinapis  Wood White           Insecta
# 101936  Leptidea sinapis  Wood White           Insecta
# 103205  Leptidea sinapis  Wood White           Insecta
# 107365  Leptidea sinapis  Wood White           Insecta
# 108329  Leptidea sinapis  Wood White           Insecta
# 115152  Leptidea sinapis  Wood White           Insecta
# 134990  Leptidea sinapis  Wood White           Insecta
# 140985  Leptidea sinapis  Wood White           Insecta
# 140986  Leptidea sinapis  Wood White           Insecta
# 174040  Leptidea sinapis  Wood White           Insecta
# 193162  Leptidea sinapis  Wood White           Insecta
# 234974  Leptidea sinapis         NaN           Insecta
# 237760  Leptidea sinapis  Wood White           Insecta
# 247598  Leptidea sinapis  Wood White           Insecta
# 247853  Leptidea sinapis  Wood White           Insecta
# 252716  Leptidea sinapis         NaN           Insecta
# 263188  Leptidea sinapis  Wood White           Insecta
# 272342  Leptidea sinapis  Wood White           Insecta
# 286903  Leptidea sinapis         NaN           Insecta
# 297049  Leptidea sinapis         NaN           Insecta
# 299161  Leptidea sinapis         NaN           Insecta
# 300645  Leptidea sinapis         NaN           Insecta

# %% [markdown]
# As there are some instances where the `common_name` column is missing, but the `scientific_name` column is the same as other rows that have a non-missing `common_name`, we can copy the values of the non-missing `common_name` to fill in the missing values.

# %%
# Fill missing common names with 'Wood White' for Leptidea sinapis
data.loc[data['scientific_name'] == 'Leptidea sinapis', 'common_name'] = data.loc[data['scientific_name'] == 'Leptidea sinapis', 'common_name'].fillna('Wood White')

# Print the updated rows
data.loc[data['scientific_name'] == 'Leptidea sinapis']
# Out:
#                id                                          image_url  \
# 40298    15382084  https://inaturalist-open-data.s3.amazonaws.com...
# 44516    16896561  https://inaturalist-open-data.s3.amazonaws.com...
# 50741    19247806  https://inaturalist-open-data.s3.amazonaws.com...
# 58898    22762965  https://static.inaturalist.org/photos/35275688...
# 59027    22831485  https://inaturalist-open-data.s3.amazonaws.com...
# 64060    25905213  https://static.inaturalist.org/photos/40140062...
# 79322    31351142  https://inaturalist-open-data.s3.amazonaws.com...
# 101936   41908484  https://inaturalist-open-data.s3.amazonaws.com...
# 103205   42480138  https://inaturalist-open-data.s3.amazonaws.com...
# 107365   45149613  https://static.inaturalist.org/photos/71584977...
# 108329   45657377  https://inaturalist-open-data.s3.amazonaws.com...
# 115152   49051665  https://inaturalist-open-data.s3.amazonaws.com...
# 134990   57330320  https://inaturalist-open-data.s3.amazonaws.com...
# 140985   59880178  https://inaturalist-open-data.s3.amazonaws.com...
# 140986   59880498  https://inaturalist-open-data.s3.amazonaws.com...
# 174040   78499732  https://inaturalist-open-data.s3.amazonaws.com...
# 193162   88578969  https://inaturalist-open-data.s3.amazonaws.com...
# 234974  111026645  https://inaturalist-open-data.s3.amazonaws.com...
# 237760  112822538  https://inaturalist-open-data.s3.amazonaws.com...
# 247598  120067723  https://inaturalist-open-data.s3.amazonaws.com...
# 247853  120198072  https://inaturalist-open-data.s3.amazonaws.com...
# 252716  123045521  https://static.inaturalist.org/photos/20840729...
# 263188  128794872  https://inaturalist-open-data.s3.amazonaws.com...
# 272342  133913132  https://static.inaturalist.org/photos/22817324...
# 286903  143708570  https://inaturalist-open-data.s3.amazonaws.com...
# 297049  150355290  https://inaturalist-open-data.s3.amazonaws.com...
# 299161  151866366  https://inaturalist-open-data.s3.amazonaws.com...
# 300645  152977712  https://inaturalist-open-data.s3.amazonaws.com...
#
#          scientific_name common_name iconic_taxon_name
# 40298   Leptidea sinapis  Wood White           Insecta
# 44516   Leptidea sinapis  Wood White           Insecta
# 50741   Leptidea sinapis  Wood White           Insecta
# 58898   Leptidea sinapis  Wood White           Insecta
# 59027   Leptidea sinapis  Wood White           Insecta
# 64060   Leptidea sinapis  Wood White           Insecta
# 79322   Leptidea sinapis  Wood White           Insecta
# 101936  Leptidea sinapis  Wood White           Insecta
# 103205  Leptidea sinapis  Wood White           Insecta
# 107365  Leptidea sinapis  Wood White           Insecta
# 108329  Leptidea sinapis  Wood White           Insecta
# 115152  Leptidea sinapis  Wood White           Insecta
# 134990  Leptidea sinapis  Wood White           Insecta
# 140985  Leptidea sinapis  Wood White           Insecta
# 140986  Leptidea sinapis  Wood White           Insecta
# 174040  Leptidea sinapis  Wood White           Insecta
# 193162  Leptidea sinapis  Wood White           Insecta
# 234974  Leptidea sinapis  Wood White           Insecta
# 237760  Leptidea sinapis  Wood White           Insecta
# 247598  Leptidea sinapis  Wood White           Insecta
# 247853  Leptidea sinapis  Wood White           Insecta
# 252716  Leptidea sinapis  Wood White           Insecta
# 263188  Leptidea sinapis  Wood White           Insecta
# 272342  Leptidea sinapis  Wood White           Insecta
# 286903  Leptidea sinapis  Wood White           Insecta
# 297049  Leptidea sinapis  Wood White           Insecta
# 299161  Leptidea sinapis  Wood White           Insecta
# 300645  Leptidea sinapis  Wood White           Insecta

# %% [markdown]
# Now I'll check if the problem is solved.

# %%
def check_common_name_variations(group):
    has_nan = group['common_name'].isna().any()
    has_value = group['common_name'].notna().any()
    return has_nan and has_value

groups = data.groupby('scientific_name')
duplicates_with_varied_common_names = groups.apply(check_common_name_variations)
duplicates_with_varied_common_names = duplicates_with_varied_common_names[duplicates_with_varied_common_names]

print(f"There is {len(duplicates_with_varied_common_names)} scientific name where some common name values are missing.")
print(duplicates_with_varied_common_names)
# Out:
# There is 0 scientific name where some common name values are missing.
# Series([], dtype: bool)

# %%
# Check for missing values in the common_name column
missing_common_names = data['common_name'].isnull()

# Count the number of missing common names
num_missing_common_names = missing_common_names.sum()

# Print the number of missing common names
print(f"There are {num_missing_common_names} missing common names in the data.")
# Out:
# There are 27760 missing common names in the data.

# %% [markdown]
# Although some of the missing values have been filled in, there are still many values missing in the `common_name` column. To investigate this further, I am going to check which `common_name` values are missing for each unique `scientific_name`.

# %%
# Count the number of missing values per scientific name
missing_values_by_name = data.groupby('scientific_name')['common_name'].apply(lambda x: x.isnull().sum())

# Sort the rows by the number of missing values in descending order
missing_values_by_name = missing_values_by_name.sort_values(ascending=False)

# Print the resulting DataFrame
missing_values_by_name.head(10)
# Out:
# scientific_name
# Acanthocephala terminalis    158
# Carabus coriaceus             87
# Acleris                       79
# Laphria thoracica             74
# Issus coleoptratus            63
# Citheronia laocoon            61
# Phoneutria depilata           59
# Leptoglossus zonatus          55
# Pantherodes pardalaria        52
# Ernolatia moorei              49
# Name: common_name, dtype: int64

# %%
# Fill missing common names with 'eurema salome' for Abaeis salome jamapa
data.loc[data['scientific_name'] == 'Abaeis salome jamapa', 'common_name'] = 'Eurema Salome'
data.loc[data['scientific_name'] == 'Acanthocephala terminalis', 'common_name'] = 'Leaf Footed Bug'
data.loc[data['scientific_name'] == 'Carabus coriaceus', 'common_name'] = 'Leather Beetle'
data.loc[data['scientific_name'] == 'Laphria thoracica', 'common_name'] = 'Pebble Bee Robberfly'
data.loc[data['scientific_name'] == 'Citheronia laocoon', 'common_name'] = 'Laocoon Sphinx Moth'

# %% [markdown]
# Since there are too many missing `common_name` values to check every one of them individually, I am going to fill the remaining empty values in the `common_name` column with the corresponding value in the `scientific_name` column.

# %%
# Fill missing common names with the scientific name
data['common_name'] = data['common_name'].fillna(data['scientific_name'])
# Out:
# C:\Users\Warmtebron\AppData\Local\Temp\ipykernel_9680\3585148853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['common_name'] = data['common_name'].fillna(data['scientific_name'])

# %%
# Check for missing values in the common_name column
missing_common_names = data['common_name'].isnull()

# Count the number of missing common names
num_missing_common_names = missing_common_names.sum()

# Print the number of missing common names
print(f"There are {num_missing_common_names} missing common names in the data.")
# Out:
# There are 0 missing common names in the data.

# %%
data.isnull().sum()
# Out:
# id                   0
# image_url            0
# scientific_name      0
# common_name          0
# iconic_taxon_name    0
# dtype: int64

# %% [markdown]
# I have removed all the empty values from the dataset

# %% [markdown]
# ## 3. Check for duplicated names.
#
# ### Check for duplicate common names in the dataset
# I will verify if there are any instances of different common name values for the same scientific name.

# %%
# Find scientific names with more than one unique common name
duplicates = data.groupby('scientific_name')['common_name'].nunique()
duplicates = duplicates[duplicates > 1]

# Print the duplicates (if any)
if len(duplicates) > 0:
    for name in duplicates.index:
        print(f"Scientific Name: {name}")
        subset = data[data['scientific_name'] == name]
        counts = subset.groupby('common_name').size()
        print(counts)
else:
    print("No scientific names have multiple unique common names.")
# Out:
# Scientific Name: Enoplognatha ovata
# common_name
# Candy-striped Spider complex    3
# Common candy-striped spider     9
# dtype: int64

# %%
# Find scientific names with more than one unique common name
duplicates = data.groupby('scientific_name')['common_name'].nunique()
duplicates = duplicates[duplicates > 1]

# Replace different common names with the same name for each scientific name
for name in duplicates.index:
    subset = data[data['scientific_name'] == name]
    new_common_name = subset['common_name'].mode().values[0]
    data.loc[data['scientific_name'] == name, 'common_name'] = new_common_name

# Print the duplicates (if any)
if len(duplicates) > 0:
    for name in duplicates.index:
        print(f"Scientific Name: {name}")
        subset = data[data['scientific_name'] == name]
        counts = subset.groupby('common_name').size()
        print(counts)
else:
    print("No scientific names have multiple unique common names.")
# Out:
# Scientific Name: Enoplognatha ovata
# common_name
# Common candy-striped spider    12
# dtype: int64

# %% [markdown]
# ### Change dutch names to English
#
# I cannot check the entire dataset for Dutch names, but I will make changes to the ones I can find

# %%
data.head(20)
# Out:
#       id                                          image_url  \
# 0     39  https://inaturalist-open-data.s3.amazonaws.com...
# 1     40  https://inaturalist-open-data.s3.amazonaws.com...
# 2     80  https://inaturalist-open-data.s3.amazonaws.com...
# 3    203  http://static.inaturalist.org/photos/132/mediu...
# 4    523  https://inaturalist-open-data.s3.amazonaws.com...
# 5    531  http://static.inaturalist.org/photos/606/mediu...
# 6    675  https://inaturalist-open-data.s3.amazonaws.com...
# 7   1227  https://inaturalist-open-data.s3.amazonaws.com...
# 8   1233  https://inaturalist-open-data.s3.amazonaws.com...
# 9   1749  https://inaturalist-open-data.s3.amazonaws.com...
# 10  1782  https://inaturalist-open-data.s3.amazonaws.com...
# 11  1952  https://inaturalist-open-data.s3.amazonaws.com...
# 12  2220  http://static.inaturalist.org/photos/2802/medi...
# 13  2312  https://inaturalist-open-data.s3.amazonaws.com...
# 14  2394  https://inaturalist-open-data.s3.amazonaws.com...
# 15  2395  https://inaturalist-open-data.s3.amazonaws.com...
# 16  3003  https://inaturalist-open-data.s3.amazonaws.com...
# 17  3180  https://inaturalist-open-data.s3.amazonaws.com...
# 18  3342  https://inaturalist-open-data.s3.amazonaws.com...
# 19  3361  https://inaturalist-open-data.s3.amazonaws.com...
#
#                        scientific_name                   common_name  \
# 0                       Taricha torosa               California Newt
# 1                       Taricha torosa               California Newt
# 2              Callisaurus draconoides           Zebra-tailed Lizard
# 3                    Arctia virginalis         Ranchman's Tiger Moth
# 4                  Malacosoma disstria  Forest Tent Caterpillar Moth
# 5                  Halysidota harrisii         Sycamore Tussock Moth
# 6                Apatelodes torrefacta       Spotted Apatelodes Moth
# 7        Thamnophis elegans terrestris            Coast Garter Snake
# 8   Hypsiglena ochrorhynchus nuchalata         California Nightsnake
# 9                    Pseudacris sierra             Sierran Tree Frog
# 10                     Caretta caretta        Onechte Karetschildpad
# 11                 Gopherus polyphemus               Gopher Tortoise
# 12          Alligator mississippiensis          Mississippialligator
# 13                      Taricha torosa               California Newt
# 14          Crotalus oreganus oreganus  Northern Pacific Rattlesnake
# 15                  Tantilla planiceps    Western Black-headed Snake
# 16                    Eudocima homaena              Eudocima homaena
# 17                    Uroctonus mordax       Western Forest Scorpion
# 18                 Boisea rubrolineata          Western Boxelder Bug
# 19                    Leucauge venusta             Orchard Orbweaver
#
#    iconic_taxon_name
# 0           Amphibia
# 1           Amphibia
# 2           Reptilia
# 3            Insecta
# 4            Insecta
# 5            Insecta
# 6            Insecta
# 7           Reptilia
# 8           Reptilia
# 9           Amphibia
# 10          Reptilia
# 11          Reptilia
# 12          Reptilia
# 13          Amphibia
# 14          Reptilia
# 15          Reptilia
# 16           Insecta
# 17         Arachnida
# 18           Insecta
# 19         Arachnida

# %%
data.tail(20)
# Out:
#                id                                          image_url  \
# 303660  156331043  https://inaturalist-open-data.s3.amazonaws.com...
# 303661  156331051  https://inaturalist-open-data.s3.amazonaws.com...
# 303662  156333234  https://inaturalist-open-data.s3.amazonaws.com...
# 303663  156334904  https://inaturalist-open-data.s3.amazonaws.com...
# 303664  156339954  https://static.inaturalist.org/photos/27033005...
# 303665  156341197  https://inaturalist-open-data.s3.amazonaws.com...
# 303666  156346675  https://inaturalist-open-data.s3.amazonaws.com...
# 303667  156349666  https://static.inaturalist.org/photos/27034925...
# 303668  156351589  https://static.inaturalist.org/photos/27035364...
# 303669  156355036  https://static.inaturalist.org/photos/27036014...
# 303670  156357080  https://inaturalist-open-data.s3.amazonaws.com...
# 303671  156366926  https://inaturalist-open-data.s3.amazonaws.com...
# 303672  156370849  https://inaturalist-open-data.s3.amazonaws.com...
# 303673  156378447  https://static.inaturalist.org/photos/27040688...
# 303674  156381433  https://inaturalist-open-data.s3.amazonaws.com...
# 303675  156384671  https://static.inaturalist.org/photos/27041880...
# 303676  156387550  https://inaturalist-open-data.s3.amazonaws.com...
# 303677  156391245  https://static.inaturalist.org/photos/27043003...
# 303678  156392005  https://inaturalist-open-data.s3.amazonaws.com...
# 303679  156400272  https://inaturalist-open-data.s3.amazonaws.com...
#
#                    scientific_name                      common_name  \
# 303660        Crotaphytus collaris          Eastern Collared Lizard
# 303661        Crotaphytus collaris          Eastern Collared Lizard
# 303662  Alligator mississippiensis             Mississippialligator
# 303663                    Crotalus                     Rattlesnakes
# 303664        Crotaphytus collaris          Eastern Collared Lizard
# 303665     Sceloporus occidentalis             Western Fence Lizard
# 303666              Hyla squirella                Squirrel Treefrog
# 303667          Hylorina sylvatica              Emerald Forest Frog
# 303668    Hypsiglena ochrorhynchus                Coast Night Snake
# 303669              Testudo graeca             Moorse Landschildpad
# 303670          Kinosternon baurii               Striped Mud Turtle
# 303671           Crotalus cerastes                       Sidewinder
# 303672            Uta stansburiana      Common Side-blotched Lizard
# 303673              Crotalus ruber          Red Diamond Rattlesnake
# 303674              Chelonia mydas                    Soepschildpad
# 303675  Duttaphrynus melanostictus                Asian Common Toad
# 303676                   Bufo bufo                       Gewone Pad
# 303677         Crotalus adamanteus  Eastern Diamondback Rattlesnake
# 303678                Hyla arborea                       Boomkikker
# 303679            Zamenis scalaris                        Trapslang
#
#        iconic_taxon_name
# 303660          Reptilia
# 303661          Reptilia
# 303662          Reptilia
# 303663          Reptilia
# 303664          Reptilia
# 303665          Reptilia
# 303666          Amphibia
# 303667          Amphibia
# 303668          Reptilia
# 303669          Reptilia
# 303670          Reptilia
# 303671          Reptilia
# 303672          Reptilia
# 303673          Reptilia
# 303674          Reptilia
# 303675          Amphibia
# 303676          Amphibia
# 303677          Reptilia
# 303678          Amphibia
# 303679          Reptilia

# %%
data['common_name'] = data['common_name'].replace({
    'Boomkikker': 'European Tree Frog',
    'Gewone Pad': 'Common Toad',
    # Add more replacements as needed
})
# Out:
# C:\Users\Warmtebron\AppData\Local\Temp\ipykernel_9680\369356330.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['common_name'] = data['common_name'].replace({

# %% [markdown]
# ## Add a column indicating whether the species is dangerous.

# %%
data
# Out:
#                id                                          image_url  \
# 0              39  https://inaturalist-open-data.s3.amazonaws.com...
# 1              40  https://inaturalist-open-data.s3.amazonaws.com...
# 2              80  https://inaturalist-open-data.s3.amazonaws.com...
# 3             203  http://static.inaturalist.org/photos/132/mediu...
# 4             523  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 303675  156384671  https://static.inaturalist.org/photos/27041880...
# 303676  156387550  https://inaturalist-open-data.s3.amazonaws.com...
# 303677  156391245  https://static.inaturalist.org/photos/27043003...
# 303678  156392005  https://inaturalist-open-data.s3.amazonaws.com...
# 303679  156400272  https://inaturalist-open-data.s3.amazonaws.com...
#
#                    scientific_name                      common_name  \
# 0                   Taricha torosa                  California Newt
# 1                   Taricha torosa                  California Newt
# 2          Callisaurus draconoides              Zebra-tailed Lizard
# 3                Arctia virginalis            Ranchman's Tiger Moth
# 4              Malacosoma disstria     Forest Tent Caterpillar Moth
# ...                            ...                              ...
# 303675  Duttaphrynus melanostictus                Asian Common Toad
# 303676                   Bufo bufo                      Common Toad
# 303677         Crotalus adamanteus  Eastern Diamondback Rattlesnake
# 303678                Hyla arborea               European Tree Frog
# 303679            Zamenis scalaris                        Trapslang
#
#        iconic_taxon_name
# 0               Amphibia
# 1               Amphibia
# 2               Reptilia
# 3                Insecta
# 4                Insecta
# ...                  ...
# 303675          Amphibia
# 303676          Amphibia
# 303677          Reptilia
# 303678          Amphibia
# 303679          Reptilia
#
# [303666 rows x 5 columns]

# %%
unique_species = data.drop_duplicates(subset='scientific_name')
unique_species.iloc[1150:1200]['scientific_name']
# Out:
# 1830           Mantidactylus cowanii
# 1832             Pseudoleon superbus
# 1834    Lycognathophis seychellensis
# 1835                 Kaloula pulchra
# 1836                 Anolis ricordii
# 1841     Lycodryas pseudogranuliceps
# 1842             Astrochelys radiata
# 1844       Madagascarophis ocellatus
# 1847              Furcifer lateralis
# 1848                   Hyles lineata
# 1850              Varanus marmoratus
# 1854                Ballus armadillo
# 1857          Schistocerca damnifica
# 1858              Phidippus princeps
# 1860                  Thereva comata
# 1861                Testudo hermanni
# 1865              Ambystoma rosaceum
# 1867                      Pelophylax
# 1871               Tantilla gracilis
# 1874                 Hamadryas arete
# 1875                Vanessa atalanta
# 1879                 Ischnura posita
# 1880                Dolomedes triton
# 1883            Amphiuma tridactylum
# 1885           Anolis microlepidotus
# 1886            Boreocanthon simplex
# 1891                 Sauromalus ater
# 1897            Regina septemvittata
# 1899            Calopteryx dimidiata
# 1909              Admetovis oxymorus
# 1912             Cophosaurus texanus
# 1918              Dorymyrmex insanus
# 1921               Trionyx triunguis
# 1922           Hippodamia convergens
# 1924               Cicindela repanda
# 1927            Malacosoma americana
# 1928              Callophrys henrici
# 1939              Terrapene coahuila
# 1940                Ischnura cervula
# 1941                Anthocharis sara
# 1943            Oncopeltus fasciatus
# 1944             Bombus californicus
# 1946               Laphria macquarti
# 1947                 Phidippus audax
# 1951             Crotalus scutulatus
# 1953             Rhinella macrorhina
# 1956                 Bombus vandykei
# 1957                   Catocala ilia
# 1958              Limenitis lorquini
# 1961                 Atlides halesus
# Name: scientific_name, dtype: object

# %%
#Number of unique species in dataset
num_rows = unique_species.shape[0]
print("Number of rows in unique species dataframe:", num_rows)
# Out:
# Number of rows in unique species dataframe: 21183

# %%
import ast

# Load the dangerous_species dictionary from a text file
with open('dangerous_species.txt', 'r') as f:
    dangerous_species_str = f.read()
    dangerous_species = ast.literal_eval(dangerous_species_str)

# Update the dangerous and reason columns in the DataFrame based on the dangerous_species dictionary
for species, reason in dangerous_species.items():
    data.loc[data["scientific_name"] == species, "dangerous"] = True
    data.loc[data["scientific_name"] == species, "reason"] = reason

# Not dangerous
data.loc[data['scientific_name'] == 'Actias luna', 'dangerous'] = False
data.loc[data['scientific_name'] == 'Antheraea polyphemus', 'dangerous'] = False
data.loc[data['scientific_name'] == 'Thamnophis sirtalis', 'dangerous'] = False
data.loc[data['scientific_name'] == 'Sceloporus occidentalis', 'dangerous'] = False
data.loc[data['scientific_name'] == 'Cicada orni', 'dangerous'] = False
data.loc[data['scientific_name'] == 'Sympetrum', 'dangerous'] = False
data.loc[data['scientific_name'] == 'Bombus', 'dangerous'] = False

# %%
# Fill all other rows with False
data.loc[0:1961, 'dangerous'] = data.loc[0:1961, 'dangerous'].fillna(False)

# %%
data
# Out:
#                id                                          image_url  \
# 0              39  https://inaturalist-open-data.s3.amazonaws.com...
# 1              40  https://inaturalist-open-data.s3.amazonaws.com...
# 2              80  https://inaturalist-open-data.s3.amazonaws.com...
# 3             203  http://static.inaturalist.org/photos/132/mediu...
# 4             523  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 303675  156384671  https://static.inaturalist.org/photos/27041880...
# 303676  156387550  https://inaturalist-open-data.s3.amazonaws.com...
# 303677  156391245  https://static.inaturalist.org/photos/27043003...
# 303678  156392005  https://inaturalist-open-data.s3.amazonaws.com...
# 303679  156400272  https://inaturalist-open-data.s3.amazonaws.com...
#
#                    scientific_name                      common_name  \
# 0                   Taricha torosa                  California Newt
# 1                   Taricha torosa                  California Newt
# 2          Callisaurus draconoides              Zebra-tailed Lizard
# 3                Arctia virginalis            Ranchman's Tiger Moth
# 4              Malacosoma disstria     Forest Tent Caterpillar Moth
# ...                            ...                              ...
# 303675  Duttaphrynus melanostictus                Asian Common Toad
# 303676                   Bufo bufo                      Common Toad
# 303677         Crotalus adamanteus  Eastern Diamondback Rattlesnake
# 303678                Hyla arborea               European Tree Frog
# 303679            Zamenis scalaris                        Trapslang
#
#        iconic_taxon_name dangerous  \
# 0               Amphibia      True
# 1               Amphibia      True
# 2               Reptilia     False
# 3                Insecta     False
# 4                Insecta     False
# ...                  ...       ...
# 303675          Amphibia      True
# 303676          Amphibia      True
# 303677          Reptilia       NaN
# 303678          Amphibia       NaN
# 303679          Reptilia       NaN
#
#                                                    reason
# 0       Contains tetrodotoxin (TTX), a potent neurotox...
# 1       Contains tetrodotoxin (TTX), a potent neurotox...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 303675  May secrete a toxic skin secretion if threaten...
# 303676  Secretes toxic skin secretions if threatened, ...
# 303677                                                NaN
# 303678                                                NaN
# 303679                                                NaN
#
# [303666 rows x 7 columns]

# %%
empty_values = data['dangerous'].isna().sum()
print(f"Number of empty values in 'dangerous' column: {empty_values}")
# Out:
# Number of empty values in 'dangerous' column: 240990

# %%
unique_species_data = data.drop_duplicates(subset=['scientific_name'], keep='first')
empty_values = unique_species_data['dangerous'].isna().sum()
print(f"Number of empty values in 'dangerous' column for unique species: {empty_values}")
# Out:
# Number of empty values in 'dangerous' column for unique species: 19975

# %% [markdown]
# Sort data on most populair

# %%
sorted_data = data.sort_values(by='scientific_name', key=lambda x: x.map(data['scientific_name'].value_counts()), ascending=False)

# %%
sorted_data.head(40000)
# Out:
#                id                                          image_url  \
# 145137   61894454  https://inaturalist-open-data.s3.amazonaws.com...
# 285908  142932173  https://static.inaturalist.org/photos/24511799...
# 196083   89991856  https://inaturalist-open-data.s3.amazonaws.com...
# 277441  137149742  https://inaturalist-open-data.s3.amazonaws.com...
# 46274    17542504  https://static.inaturalist.org/photos/26705436...
# ...           ...                                                ...
# 88062    34914789  https://inaturalist-open-data.s3.amazonaws.com...
# 134280   57057035  https://static.inaturalist.org/photos/90979168...
# 44963    17069869  https://static.inaturalist.org/photos/25854905...
# 136057   57755439  https://static.inaturalist.org/photos/92154234...
# 73984    29569324  https://inaturalist-open-data.s3.amazonaws.com...
#
#            scientific_name            common_name iconic_taxon_name dangerous  \
# 145137    Danaus plexippus                Monarch           Insecta      True
# 285908    Danaus plexippus                Monarch           Insecta      True
# 196083    Danaus plexippus                Monarch           Insecta      True
# 277441    Danaus plexippus                Monarch           Insecta      True
# 46274     Danaus plexippus                Monarch           Insecta      True
# ...                    ...                    ...               ...       ...
# 88062   Xylocopa virginica  Eastern Carpenter Bee           Insecta       NaN
# 134280  Xylocopa virginica  Eastern Carpenter Bee           Insecta       NaN
# 44963   Xylocopa virginica  Eastern Carpenter Bee           Insecta       NaN
# 136057  Xylocopa virginica  Eastern Carpenter Bee           Insecta       NaN
# 73984   Xylocopa virginica  Eastern Carpenter Bee           Insecta       NaN
#
#                                                    reason
# 145137  Not toxic but may cause skin irritation due to...
# 285908  Not toxic but may cause skin irritation due to...
# 196083  Not toxic but may cause skin irritation due to...
# 277441  Not toxic but may cause skin irritation due to...
# 46274   Not toxic but may cause skin irritation due to...
# ...                                                   ...
# 88062                                                 NaN
# 134280                                                NaN
# 44963                                                 NaN
# 136057                                                NaN
# 73984                                                 NaN
#
# [40000 rows x 7 columns]
